# %%
import random
import matplotlib.pyplot as plt
import numpy as np

# %%
peopel = []
for i in range(50):
    peopel.append(100)

person2 = random.randrange(0,50)

for matrics in range(10000):
    for person1 in range(0,50):
        person2 = random.randrange(0,50)
        if peopel[person1] > 0:
            peopel[person1] -= 1
        if peopel[person2] > 0:
            peopel[person2] +=1
peopel.sort()

ax = plt.bar(np.arange(0,50), peopel, color = 'y', label = 'matrics')
