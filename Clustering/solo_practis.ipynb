# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs
from scipy.spatial import distance_matrix
from sklearn.cluster import AgglomerativeClustering
from scipy.cluster import hierarchy

# %%
np.random.seed(7)

# %%
x, y = make_blobs(n_samples=50, centers=[[-2, 3], [4, 2], [6, 6]], cluster_std=1.2)
plt.scatter(x[:,0], x[:,1])

# %%
model = AgglomerativeClustering(linkage='average', n_clusters=3)
model.fit(x)
# Out:
# AgglomerativeClustering(linkage='average', n_clusters=3)

# %%
plt.scatter(x[:,0], x[:,1], c = model.labels_)

for i in range(x.shape[0]):
    plt.text(x[i, 0], x[i, 1], str(y[i]))

# %%
dist_matrix = distance_matrix(x, x)
print(dist_matrix)
# Out:
# [[ 0.         10.18764739  2.58087134 ...  9.65165028  4.89587346
#   12.06519705]
#  [10.18764739  0.          8.81987572 ...  0.62054465  9.28753738
#    3.27259823]
#  [ 2.58087134  8.81987572  0.         ...  8.37384231  6.48942474
#   11.24263938]
#  ...
#  [ 9.65165028  0.62054465  8.37384231 ...  0.          8.66704587
#    3.31389646]
#  [ 4.89587346  9.28753738  6.48942474 ...  8.66704587  0.
#    9.80022271]
#  [12.06519705  3.27259823 11.24263938 ...  3.31389646  9.80022271
#    0.        ]]

# %%
z = hierarchy.linkage(dist_matrix, 'complete')
# Out:
# C:\Users\baransystem\AppData\Local\Temp\ipykernel_6584\2642424508.py:1: ClusterWarning: scipy.cluster: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   z = hierarchy.linkage(dist_matrix, 'complete')

# %%
dem = hierarchy.dendrogram(z)
